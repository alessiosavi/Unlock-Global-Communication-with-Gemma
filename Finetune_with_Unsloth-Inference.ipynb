# %% [markdown]
# ##### Copyright 2024 Google LLC.

# %%
# %pip install --upgrade --no-cache-dir pip wheel setuptools black isort jupyterlab-code-formatter jupyterthemes jupyterlab_darkside_theme nvitop
# %pip install --upgrade --no-cache-dir torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# %pip install --upgrade --no-cache-dir torcheval optuna torchmetrics torchtnt
# %pip install --upgrade --no-cache-dir evaluate rouge_score datasets tensorboard accelerate flash-attn torchtnt bitsandbytes transformers
# %pip install --upgrade --no-cache-dir unsloth
# %pip install --upgrade --no-cache-dir trl
# # # !rm ~/.cache/matplotlib -rf

# %% [markdown]
# # FIXME
# - Translate topic (aka wikipedia page) in a standard language (English)
# - For venetian language, use "decoded" translation (no phonetic symbols)
# - Remove batch of text that are below 50 words

# %%
import gc
import gzip
import json
import os
import pickle
import re
import string
from collections import defaultdict
from copy import copy
from typing import *

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
from datasets import Dataset, load_dataset
from tqdm.auto import tqdm
from transformers import (
    AutoModel,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TextStreamer,
    TrainingArguments,
)
from trl import SFTTrainer
from unsloth import FastLanguageModel, is_bfloat16_supported

batch_regex = re.compile(r"(?<=[.!?\n])\s+")
punctuation_set = set(string.punctuation)
number_regex = re.compile(r"\d*\.\d+|\d+", re.MULTILINE)

tqdm.pandas()
os.environ["HF_TOKEN"] = "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"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"


def _collect():
    x = 0
    for i in range(3):
        x += gc.collect()
        torch.cuda.empty_cache()
    return x
# Out:
# 2025-01-02 10:17:21.609672: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-02 10:17:21.609741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-02 10:17:21.611443: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-02 10:17:21.620902: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
from typing import *

import nltk.translate.bleu_score as bleu
import nltk.translate.gleu_score as gleu


def sentence_metric(translated: str, original: str, metric=gleu) -> float:
    method_name = [name for name in metric.__dict__.keys() if "sentence" in name][0]
    score_method = getattr(metric, method_name)
    return score_method([translated.split()], original.split())


def corpus_metric(translated: List[str], original: List[str], metric=gleu) -> float:
    assert len(translated) == len(original)
    method_name = [name for name in metric.__dict__.keys() if "corpus" in name][0]
    score_method = getattr(metric, method_name)
    translated = [[sentence.split()] for sentence in translated]
    original = [sentence.split() for sentence in original]
    return score_method(translated, original)


hyp = "she read the book because she was interested in world history"
ref_a = "she read the book because she was interested in world history"
ref_b = "she was interested in world history because she read the book"
sentence_metric(ref_b, hyp), corpus_metric([ref_b, ref_b], [hyp, hyp]), sentence_metric(
    ref_b, hyp, bleu
), corpus_metric([ref_b, ref_b], [hyp, hyp], bleu)
# Out:
# (0.7894736842105263,
#  0.7894736842105263,
#  0.7400828044922853,
#  0.7400828044922853)

# %%
max_seq_length = 1024
min_seq_length = 128
model_id = "google/gemma-2-2b-it"


def load_base_model(model_id, max_seq_length, device="sequential"):
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=model_id,
        max_seq_length=max_seq_length,
        dtype=None,
        load_in_4bit=True,
        device_map=device,
        attn_implementation="flash_attention_2",
    )
    return model, tokenizer


model, tokenizer = load_base_model(
    "gemma-2-2b-it_unsloth_ia_trans-desc_v7-3epoch-lm_head", max_seq_length
)
_collect()
FastLanguageModel.for_inference(model)
# Out:
# ==((====))==  Unsloth 2024.12.12: Fast Gemma2 patching. Transformers: 4.47.1.
#    \\   /|    GPU: Tesla V100-SXM2-16GB. Max memory: 15.773 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2024.12.12 patched 26 layers with 0 QKV layers, 0 O layers and 0 MLP layers.
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Gemma2ForCausalLM(
#       (model): Gemma2Model(
#         (embed_tokens): Embedding(256000, 2304, padding_idx=0)
#         (layers): ModuleList(
#           (0-25): 26 x Gemma2DecoderLayer(
#             (self_attn): Gemma2Attention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2304, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): GemmaFixedRotaryEmbedding()
#             )
#             (mlp): Gemma2MLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=9216, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=9216, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2304, out_features=9216, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2304, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=9216, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=9216, out_features=2304, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.2, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=9216, out_features=128, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=128, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): PytorchGELUTanh()
#             )
#             (input_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#             (post_attention_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#             (pre_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#             (post_feedforward_layernorm): Gemma2RMSNorm((2304,), eps=1e-06)
#           )
#         )
#         (norm): Gemma2RMSNorm((2304,), eps=1e-06)
#       )
#       (lm_head): ModulesToSaveWrapper(
#         (original_module): Linear(in_features=2304, out_features=256000, bias=False)
#         (modules_to_save): ModuleDict(
#           (default): Linear(in_features=2304, out_features=256000, bias=False)
#         )
#       )
#     )
#   )
# )

# %%
df_test = Dataset.load_from_disk("dataset_test.hf").to_pandas()

# %%
df_test.sample(1).to_dict(orient="records")
# Out:
# [{'topic': 'Ixola de Ariàn',
#   'original_content': "Xe oncora parçialmente vixibiłi, soravisùe a atività scriteriàe de cava, alcune dune fosili, testimoniança dei vechi cordoni litoranei de confin col mar, che se ga formà in diverse faxe fin a più de 2000 ani fa. Aluvion \nFin a la costruçion de i grandi arzeri inte el XX secolo, l'Ixola xe stà sogeta a aluvion continue. L'Ixola de Ariàn no xe stà coinvolta inte l'aluvione del 1951; la ga parò subito in ani recenti do alluvion, dovùe a la rota de l'arzere del Po de Goro;\n el 20 de zugno 1957, la rota in località Ca' Vendramin ga meso sota çirca 7\xa0700 etari; \n el 2 de novenbre 1960, la rota a Riva' ga lagà çirca 800 ettari. Voxe corelae \n Delta del Po\n Tajo de Porto Viro\n Ariàn\nAriàn\nPàjine co erori inte łe mape",
#   'translated_content': "It is still partially visible, surviving the excavations of, among other things, a fossil, testifying to the old coastline that was formed in different phases up to over 2000 years ago.\n\nUntil the construction of the large dam in the 20th century, the island was subject to continuous flooding. The island of Ariano was not affected by the flood of 1951; it suffered two floods in recent years due to the rupture of the Goro River bank;\n\n- On June 20, 1957, the rupture in the locality of Ca 'Vendramin put about 7,700 hectares underwater;\n- On November 2, 1960, the rupture in Riva 'put about 800 hectares underwater.\n\nRelated voices\n\n* Delta of the Po\n* Tajo of Porto Viro\n* Ariano\n* Ariano\n* Pages with errors in the Map",
#   'prompt': "<start_of_turn>user\nDescribe the following topic in venetian.\n\nIxola de Ariàn<end_of_turn>\n<start_of_turn>model\nXe oncora parçialmente vixibiłi, soravisùe a atività scriteriàe de cava, alcune dune fosili, testimoniança dei vechi cordoni litoranei de confin col mar, che se ga formà in diverse faxe fin a più de 2000 ani fa. Aluvion \nFin a la costruçion de i grandi arzeri inte el XX secolo, l'Ixola xe stà sogeta a aluvion continue. L'Ixola de Ariàn no xe stà coinvolta inte l'aluvione del 1951; la ga parò subito in ani recenti do alluvion, dovùe a la rota de l'arzere del Po de Goro;\n el 20 de zugno 1957, la rota in località Ca' Vendramin ga meso sota çirca 7\xa0700 etari; \n el 2 de novenbre 1960, la rota a Riva' ga lagà çirca 800 ettari. Voxe corelae \n Delta del Po\n Tajo de Porto Viro\n Ariàn\nAriàn\nPàjine co erori inte łe mape<end_of_turn><eos>",
#   'starting_language': 'venetian',
#   'translated_language': 'english',
#   'task_type': 'describe',
#   'new_lines_ratio': 0.08904109589041095,
#   'n_tokens': 287,
#   'len_ratio': 1.0227272727272727,
#   'len': 146,
#   'id': 28808,
#   '__index_level_0__': 6608}]

# %%
df_test["hash"] = df_test.apply(
    lambda x: hash(
        x["topic"]
        + "|"
        + x["original_content"]
        + "|"
        + x["translated_content"]
        + "|"
        + x["starting_language"]
        + "|"
        + x["translated_language"]
        + "|"
        + x["task_type"]
        + "|"
    ),
    axis=1,
)

# %%
instruction_translate = "Provide a direct translation of the following text from **{}** to **{}**, without any additions, explanations, or interpretations."
alpaca_prompt_template = """<start_of_turn>user
{}

{}<end_of_turn>
<start_of_turn>model"""

# %%
df_test["question"] = df_test.apply(
    lambda row: alpaca_prompt_template.format(
        instruction_translate.format(
            row["starting_language"], row["translated_language"]
        ),
        row["original_content"],
    ),
    axis=1,
)

# %%
test_dataset = pd.DataFrame()
for group, _df in df_test.groupby(
    ["starting_language", "translated_language", "task_type"]
):
    if 'task_type' == 'describe':
        continue
    test_dataset = pd.concat([test_dataset, _df.sample(3, random_state=42)])

# %%
def tokenize_for_inference(entries: List[str], tokenizer=tokenizer, to_gpu=False):
    tokenized = [
        tokenizer(
            entry,
            padding=False,
            truncation=False,
            return_tensors="pt",
            add_special_tokens=False,
        )
        for entry in entries
    ]
    if to_gpu:
        [entry.to("cuda") for entry in tokenized]
    return tokenized


MODEL_START_TOKEN = "<start_of_turn>model"


def extract_response(model_responses: List[str]):
    responses = []
    for response in model_responses:
        n = response.find(MODEL_START_TOKEN)
        responses.append(
            response[n:]
            .removeprefix(MODEL_START_TOKEN)
            .removesuffix("<end_of_turn>")
            .strip()
        )
    return responses


inputs = tokenize_for_inference(test_dataset["question"].to_list(), to_gpu=True)
outputs = test_dataset["translated_content"].to_list()
ids = test_dataset["hash"].to_list()

# %%
for input_entry, output_entry in zip(inputs, outputs):
    print(tokenizer.batch_decode(input_entry["input_ids"])[0])
    print("---" * 30)
    print(output_entry)
    print("===" * 30)
    break
# Out:
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **interlingua**, without any additions, explanations, or interpretations.
#
# Ike Turner struggled with cocaine addiction and legal problems in the following years . Tina Turner revealed that he had committed domestic violence during their marriage , which was depicted in her 1986 autobiography and the 1993 film What 's Love Got to Do with It . Ike Turner spent 18 months in prison in the early 1990s . In the final years of his life , Turner used drugs less often and had a commercial and artistic rebirth . He returned to blues music , released two acclaimed albums and went on concert tours . Turner is noted for his innovations in music . He won five Grammy Awards , an induction ( with his ex-wife ) into the Rock and Roll Hall of Fame in 1991 and many other awards . The magazine Rolling Stone included him in their list of the 100 Best Guitarists .<end_of_turn>
# <start_of_turn>model
# ------------------------------------------------------------------------------------------
# Ike Turner luctava con un narcomania de cocaina e problemas legal durante le annos subsequente. Tina Turner revelava ille habeva facite violentia domestic durante su maritage, que esseva depingite in su 1986 autobiographia e le 1993 film What's Love Got to Do with It?. Ike Turner passava 18 menses in prision durante le initio del annos 1990. In le final annos de su vita, Turner usava drogas minus sovente e habeva un renascienta commercial et artistic. Ille retornava a musica blues, publicava duo albumes acclamate e faceva toures de concertos. Turner es notate pro su innovationes in musica. Ille ganiava cinque Grammy Awardes, an induction (con su ex-sposa) al Rock and Roll Hall of Fame in 1991 e multe precios altere. Le magazin Rolling Stone le includeva a su lista del 100 guitarristas melior. Notas
# ==========================================================================================

# %%
_collect()
generation_config = {"max_new_tokens": max_seq_length // 2} | {
    # "do_sample": True,
    # "early_stopping" : True,
    # "temperature": 0.1,
    # "top_k": 10,
    # "top_p": 0.1,
    # "max_new_tokens": 256,
    # "repetition_penalty": 1.3,
}
with torch.inference_mode():
    res = [
        model.generate(**_input, **generation_config).detach().cpu()
        for _input in tqdm(inputs)
    ]
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]

# %%
import numpy as np

res_decode = [tokenizer.batch_decode(v) for v in res]
res_decode = np.asarray(res_decode).flatten().tolist()

# %%
pickle.dump(
    dict(zip(ids, res_decode)),
    open(f"{os.path.basename(model_id)}_base_prediction.pkl", "wb"),
    pickle.HIGHEST_PROTOCOL,
)

# %%
# pd.DataFrame([dict(zip(ids, res_decode))]).T.reset_index()

# %%
_results = []
for test_example, model_response in zip(outputs, res_decode):
    print("Test Example")
    print(test_example)
    print("---" * 30)
    print("Model Response")
    print(model_response)
    model_response = extract_response([model_response])[0]
    m = sentence_metric(model_response, test_example, bleu)
    _results.append((model_response, test_example, m))
    print(m)
    print("===" * 30)
# Out:
# Test Example
# R. le prince regente de Portugal e de Brasil, sur le citate de Olivença/Olivenza e le altere territorios cedite a Espania per le Tractato de Badajoz de 1801, e contemplante le restitution de tal objectos como un del mesuras proprie a assecurar inter le duo regnos del peninsula iste bon harmonia complete e stabile cuje conservation in tote le partes del Europa ha essite le objectivo constante de lor arrangiamentos, se ingagia formalmente a emplear in le vias del conciliation lor effortios plus efficace, a fin que le retrocession de tal territorios in favor de Portugal sia effectuate; e le Potentias recognosce, secundo lo que depende de cata un de illos, que iste arrangiamento debe haber loco le plus tosto possibile."
#  Espania sustene que Olivenza esseva conquerite per Espania e non per le Francia napoleonic, ergo le firma del tractato de Vienna esseva facite como vincitor e non pro ceder territorios legitimemente acquirite. Hodie, in le 2006, illo es ancora sub administration de Espania contestate per Portugal. Ligamines externe
#  http://www.unex.es/edafo/ComOlivenza.html
#  http://imigrantes.no.sapo.pt/olivenca2.gif
#  Citates in Espania
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **interlingua**, without any additions, explanations, or interpretations.
#
# R. the Prince Regent of Portugal and Brazil, on the city of Olivenca / Olivenza and the other ceded territory to Spain by the Treaty of Badajoz of 1801, and contemplating the restitution of such object as one of the measures proper to ensure between the two kingdoms of the peninsula the complete and stable harmony whose conservation in all of Europe has been the constant objective of their agreements, formally undertakes to employ in the way of conciliation their most effective efforts, so that the retrocession of such territory in favor of Portugal be effectuated; and the Powers recognize, according to what depends on each of them, that such arrangement should take place as soon as possible.
#
# Spain maintains that Olivenza was conquered by Spain and not by Napoleonic France, therefore the signing of the Treaty of Vienna was done as a victor and not to cede legitimately acquired territory. Today, in 2006, it is still under the administration of Spain, contested by Portugal.<end_of_turn>
# <start_of_turn>model
# Le Prince Regent de Portugal e Brasil, in le citate de Olivenca / Olivenza e le altere territorio cedite a Espania per le Tractato de Badajoz de 1801, e contemplate le restitution de tal objecto como un del mesuras proper a garantir inter le duo reinos del peninsula le complete e stabile harmonia cuje conservation in tote Europa ha essite le constante objectivo de lor acordi, formalmente se undertakes a emplear in le maniera conciliante lor plus effective effortio, que le retrocession de tal territorio in favor de Portugal sia effectuate; e le poteres recognosce, conforme a lo que depende de cada uno, que tal arrangiamento debe tener loco cuanto antes. Espania mantene que Olivenza era conquistada por Espania e no por Francia Napoleonic, por lo que le firma del Tractato de Viena se faceva como un victor e no como un ceder legitimemente adquirite territorio. Depost, in 2006, es ancora sub le administration de Espania, contestate por Portugal.<end_of_turn>
# 0.2752451749997877
# ==========================================================================================
# Test Example
# Le chef del stato e del ecclesia official pertine al mesme persona – le rege Carolo III. Le stato etiam garanti que vinti-sex episcopos del Ecclesia de Anglaterra sia membros del camera alte del parlamento. Dunque le Regno Unite non pote esser considerate un stato secular. Intertanto, es bon clarificar que un Stato Secular non implica le elimination del religion. Al contrario, le Stato Laic debe garantir le libertate religiose e, de iste modo, respectar le tractos religiose que ja deveniva parte del cultura e del tradition del populo. Le presentia de un crucifixo, per exemplo, in un edificio public se justifica in le mesura in que le symbolo es un portion del memoria del pais e, in ultra, manifesta le tolerantia del Stato verso le personas religiose. Le fide es un derecto natural que antecede mesmo le notion de Stato. Referentias
#  Governamento
# Philosophia politic
# Stato
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **interlingua**, without any additions, explanations, or interpretations.
#
# The head of state and head of the church pertains to the same person - King Charles III. The state also guarantees that twenty-six bishops of the Church of England are members of the upper chamber of parliament. Therefore, the United Kingdom cannot be considered a secular state. Meanwhile, it is good to clarify that a secular state does not imply the elimination of religion. On the contrary, the secular state must guarantee religious freedom and, in this way, respect the religious traits that have already become part of the culture and tradition of the people. The display of a crucifix, for example, in a public building is justified to the extent that the symbol is a part of the country's memory and, in addition, demonstrates the state's tolerance towards religious people. Faith is a natural right that precedes even the notion of state.<end_of_turn>
# <start_of_turn>model
# Le capite del stato e del ecclesia pertine al mesme persona - le rege Carolo III. Le stato etiam seque que le duo-sexte episcopos del Ecclesia Anglic esse membros del camera del parlamento. Ergo, le Regno Unite non pote esser considerate un stato seculare. In interim, il es bon clarificar que un stato seculare non implica le elimination de religion. Al contrario, le stato seculare debe garantir le libertate religiose e, in iste modo, respectar le tractos religiose que ha ja devenite parte del cultura e tradition del populo. Le exhibition de un cruce, per exemplo, in un edificio public es justificate al mesme grado que le symbolo es parte del memoria del pais e, in addition, demonstra le tolerantia del stato verso le personas religiose. Le fide es un derecto natural que preda mesmo le notion de stato.<end_of_turn>
# 0.4787403379571465
# ==========================================================================================
# Test Example
# Actualmente (augusto de 2005) il existe un grande division inter le fabricantes de un typo o altere, specialmente al hora de seliger un systema de archivos pro iste memorias. Nonobstante, nunc comencia le disveloppamento de memorias basate in ORNAND. Le systemas de archivos pro iste memorias es in plen disveloppamento anque jam in functionamento como per exemplo JFFS originalmente pro NOR, le qual habeva evoluite se a JFSS2 pro supportar cetero NAND o YAFFS, jam in su secunde version, pro NAND. Nonobstante, in le practica es empleate un systema de archivos FAT pro compatibilitate, super toto in le cartas de memoria extrahibile. Memoria e immagazinage
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **interlingua**, without any additions, explanations, or interpretations.
#
# currently (August 2005) there is a great division among manufacturers of one type or another, especially when it comes to choosing a file system for these memories. Nevertheless, the development of ORNAND-based memories has just begun. The file systems for these memories are in full development and already in operation, for example JFFS originally for NOR, which has evolved to JFFS2 to support also NAND or YAFFS, already in its second version, for NAND. Nevertheless, in practice a FAT file system is used for compatibility, above all in removable memory cards. memory and storage<end_of_turn>
# <start_of_turn>model
# Interlingua
# Traduction directe del texto del interlingua
# Interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction directe del texto del interlingua
# Traduction
# 0
# ==========================================================================================
# Test Example
# Como altere planetas gigante, le planeta Urano ha un systema de anulos, un magnetosphera, e plure satellites natural. Le systema de Urano habe un configuration unic respecto a le altere planetas proque su axe de rotation es multo inclinate, quasi usque su plano de revolution circum le sol. Por iste causa, su polo nord et sud se incontra ubi le majoria del altere planetas habe le equator. Viste ab le terra, le anulos de Urano da le aspecto de que illos circumfere le planeta como un diana, et que le satellites gira circum illo como le acos de un horologio, ma in 2007 et 2008, le anulos appareva inclinate. Le 24 de januario de 1986 le imagines del Voyager 2 monstrava Urano como un planeta sin alcuna characteristica special de luce visibile e mesmo sin bandas de nubes o tempestas associate con le altere gigantes. Tamen, le observatores terrestre ha viste signales de cambio de saison et un augmento in le activitate metereologic in le ultime annos a mesura que Urano approcha su equinoctio. Le velocitates del vento in Urano pote attinger o mesmo superpassar le 250 metros por secundo (900km/h). Urano es un del planetas que habe un rotation retrograde; le altere es Venus. Referentia
# Articulo de Urano ex Encyclopedia Britannica
#  Planetas
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **interlingua**, without any additions, explanations, or interpretations.
#
# How to alter giant planets, the planetary system of Uranus has a system of rings, a magnetosphere, and several natural satellites. The system of Uranus has a unique configuration with respect to the other planets because its axis of rotation is much inclined, almost parallel to its plane of revolution around the Sun. For this reason, its north and south poles are where the majority of the other planets have their equator. Seen from Earth, the rings of Uranus give the appearance that they are surrounding the planet like a target, and that the satellites are orbiting around it like the hands of a clock, but in 2007 and 2008, the rings appeared inclined. On January 24, 1986, the images of Voyager 2 showed Uranus as a planet without any special visible characteristics, and even without cloud bands or storms associated with the other giants. However, terrestrial observers have seen signs of a change of season and an increase in meteorological activity in the last year as Uranus approaches its equinox. The wind speed in Uranus can reach or even surpass 250 meters per second (900 km/h). Uranus is one of the planets that has a retrograde rotation; the other is Venus.<end_of_turn>
# <start_of_turn>model
# Traduction directe:
# Le systema de Urso ha un configuration unic con respecto al altere planetas proque su axe de rotation es multo inclinate, quasi parallel a su plano de revolution circa le Sol. Pro iste ration, su polos nord e sud es ubi le majoritate del altere planetas ha su equator. Viste de Terra, le ringes de Urso da le apparentia que illos circumfere le planeta como un objecto, e que le satellites orbita circa illo como le manos de un horologio, ma in 2007 e 2008, le ringes appare inclinate. Le 24 de januario 1986, le imagines de Voyager 2 monstrava Urso como un planeta sin qualcunque characteristices visibile special, e mesmo sin bandas de nubes o tempestas associate con le altere gigantes. Nonobstante, le observatores terrestre ha vidite signos de un cambio de season e un augmento in activitate meteorologic in le ultime anno como Urso approcha su equino. Le velocitate del vento in Urso pote attinger o evenexar 250 metros per secunde (900 km/h). Urso es un del planetas que ha un rotation retrograde; le altere es Venus.<end_of_turn>
# 0.3248320686274792
# ==========================================================================================
# Test Example
# Lingua del lyrica del hymno
# Hymnos national in general usa le lingua commun del pais de facto o le lingua official. Exceptiones es le hymno national de India (Jana Gana Mana) con paroles in sanskrit supra le lingua Bengali, le hymno national de Pakistan (que non es in le linguas official urdu o anglese) ma in le lingua persian, perque Pakistan ha le tradition de culmination de statos e imperios musulman in le region que usa le lingua persian. Statos con multiple linguas official como Helvetia (francese, germano, italiano e rhetoromano) e Canada ((anglese e francese ha le hymno in omne le linguas official. In Africa de Sud le hymno national es componite de stanzas in cinque linguas official. Vide etiam
#  Lista de hymnos national
#  Ligamines externe
#  Omne hymnos national (in formato MIDI)
#  Musica, lyrica de omne hymnos de paises
#  Hymnos mundial audio de US Navy
#  Un collection de hymnos national in formato mp3. NationalAnthems.us
#  Referentias
#  Stato
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **interlingua**, without any additions, explanations, or interpretations.
#
# The language of the lyrics of the anthem
# National anthems are generally sung in the de facto or official language of the country. Exceptions are the national anthem of India (Jana Gana Mana) with words in Sanskrit above the Bengali language, the national anthem of Pakistan (which is not in the official language of Urdu or English) but in the Persian language, because Pakistan has the tradition of culmination of Muslim states and empires in the region that used the Persian language. States with multiple official languages such as Switzerland (French, German, Italian and Rhaeto-Romance) and Canada (English and French have the anthem in all official languages. In South Africa the national anthem is composed of stanzas in five official languages. See also
# List of national anthems
# External links
# All national anthems (in MIDI format)
# Music, lyrics of all anthems of the country
# Worldwide audio anthems of the US Navy
# A collection of national anthems in mp3 format. NationalAnthems.us
# References
# State<end_of_turn>
# <start_of_turn>model
#
# The language of the lyrics of the anthem
# National anthems are generally sung in the de facto or official language of the country. Exceptions are the national anthem of India ( Jana Gana Mana) with words in Sanskrit above the Bengali language, the national anthem of Pakistan (which is not in the official language of Urdu or English) but in the Persian language, because Pakistan has the tradition of culmination of Muslim states and empires in the region that used the Persian language. States with multiple official languages such as Switzerland ( French, German, Italian and Rhaeto-Romance) and Canada ( English and French have the anthem in all official languages. In South Africa the national anthem is composed of stanzas in five official languages. See also
#  List of national anthems
#  External links
#  All national anthems ( in MIDI format )
#  Music, lyrics of all anthems of the country
#  Worldwide audio anthems of the US Navy
#  A collection of national anthems in mp3 format. NationalAnthems.us
#  References
#  State<end_of_turn>
# 3.900415862750144e-155
# ==========================================================================================
# Test Example
# El fumeto ga otenùo notevołe suceso co i soi speciałi tełevizivi, molti dei cuałi, come A Charlie Brown Christmas e It's the Great Pumpkin, Charlie Brown, i ga vinto o i ze stà nominati ałi Emmy Awards. Łi speciałi dełe festività dei Peanuts rimangono molto popołari e son stati trasmesi suła tełevizion de rete par oltre 50 ani prima de pasar al servisio de streaming Apple TV+ intè'l 2020. Intè'l 2013, TV Guide ga clasificò łi speciałi tełevizivi dei Peanuts come el cuarto carton animato tełevizivo piassè grande de tuti i tenpi. Lingambi foresti
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **venetian**, without any additions, explanations, or interpretations.
#
# The Peanuts specials won numerous accolades with their television specials, many of which, such as A Charlie Brown Christmas and It's the Great Pumpkin, Charlie Brown, won or were nominated for Emmy Awards. The Peanuts holiday specials remain extremely popular and were broadcast over the network airwaves for over 50 years before moving to the Apple TV+ streaming service in 2020. In 2013, TV Guide ranked the Peanuts television specials the fourth Greatest TV Cartoon of All Time.<end_of_turn>
# <start_of_turn>model
# El Peanuts i le so speciałi i ga vinto numaroxi premi. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards. I le ga vinto o i ga nominà i Emmy Awards.
# 0.0011659856545009329
# ==========================================================================================
# Test Example
# Tanti leader sociałisti musulmani i crede inte la democrasia raprexentativa o direta e inte la lexitimità da parte del popolo (elesion democrateghe), a difarensa de tuti che altri leader de partii relijoxi islameghi, che i proclama de esar i sucesori de Maometo e che i pensa la democrasia islamega so na forma teocratega, vardada male dai islamosociałisti. Exempi de sociałismo islamego xe l'ideoloxia del Libro Verde de Mu'ammar Gheddafi in Libia, chela de Fatah in Palestina, del partio Baath de Iraq (Saddam Hussein e dopo i ex sostegnidori del rexime pasà) e Siria (Hafiz e Bashar al-Assad) e dei Mojahedin del Popolo Iranian e, in pasà, el naserismo in Egito e el rexime de Ben Ali in Tunixia. Ideołoxie pułiteghe
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **venetian**, without any additions, explanations, or interpretations.
#
# Many Muslim socialist leaders believe in representative or direct democracy and the legitimacy that comes from the people (democratic election), unlike other Islamic religious party leaders, who proclaim themselves the successor of Mohammed and who believe that Islamic democracy should be a theocratic form, viewed negatively by the Islamo-socialist. Examples of Islamic socialism are the ideology of Mu'ammar Gaddafi's Green Book in Libya, Fatah's in Palestine, the Iraqi Ba'ath Party (Saddam Hussein and the former supporter of the past regime) and Syria (Hafiz and Bashar al-Assad) and the Iranian People's Mojahedin and, in the past, Nasserism in Egypt and Ben Ali's regime in Tunisia.<end_of_turn>
# <start_of_turn>model
# Many Muslim socialist leaders believe in representative or direct democracy and the legitimacy that comes from the people (democratic election), unlike other Islamic religious party leaders, who proclaim themselves the successors of Mohammed and who believe that Islamic democracy should be a theocratic form, viewed negatively by the Islamo-socialist. Examples of Islamic socialism are the ideology of Mu'ammar Gaddafi's Green Book in Libya, Fatah's in Palestine, the Iraqi Ba'ath Party (Saddam Hussein and the former supporter of the past regime) and Syria (Hafiz and Bashar al-Assad) and the Iranian People's Mojahedin and, in the past, Nasserism in Egypt and Ben Ali's regime in Tunisia.<end_of_turn>
# 3.193526156046264e-155
# ==========================================================================================
# Test Example
# I militari i ga fato on colpo de Stato in tel 1986. I militari i ga meso su on Consilio Militare soto la guida de Justin Lekhanya che el dovea governar el paexe co el re Mosheshoe II e co un grupo de ministri selti dal re. Lekhanya el volea tornar al governo democràtego in tel giunio 1992, ma on colpo de Stato el xe stà parà via in tel 1991. El re Moshoeshoe II nol ga volù tornar in Lesotho par diventar on re cerimolniale e so fiol, Letsie III, el ga preso el so posto. En tel 1995, el re Letsie el ga abdicà in favor de so pare, che parò el xe morto in un incidente de machina in tel 1996. El re Letsie III el xe tornà al trono. Da alora el Lesotho el ga sempre visù ne l’instabilità pułìtega, co amutinamenti de l’esercito e de la polisia, ma anca co tentativi de colpo de Stato. L’ultimo tentativo, in tel agosto del 1998, el ga forsà el re a domandar l’intervento de le forse de difesa de la comunità de l’Africa Australe. Soldai sudafricani, zinbabweani e del Botswana i xe entrà in tel Lesotho e portà l’ordine. L’Autorità Provisoria che la ga governà el Lesotho la ga canbià le legi eletorali par asicurarse che anca l’oposision la gavese na rapresentansa in parlamento. Łesotho
# Lesotho
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **venetian**, without any additions, explanations, or interpretations.
#
# The military will make a coup d'état in 1986. The military will govern with a military council under the leadership of Justin Lekhanya who was to govern the country with King Mosheshoe II and a group of ministers appointed by the king. Lekhanya wanted to return to democratic government in June 1992, but a coup d'état took place in 1991. King Moshoeshoe II did not want to return to Lesotho to become a ceremonial king and his son Letsie III took his place. In 1995, King Letsie abdicated in favor of his father, who however died in a car accident in 1996. King Letsie III returned to the throne. Since then Lesotho has always experienced political instability, with frequent mutinies by the army and police, but also with attempted coups d'état. The last attempt, in August 1998, forced the king to ask for the intervention of the defense forces of the Southern African community. South African, Zimbabwean and Botswana soldiers entered Lesotho and restored order. The provisional authority that governed Lesotho changed the electoral law to ensure that the opposition also had representation in parliament.<end_of_turn>
# <start_of_turn>model
# El militare el farà un colpo de Stato in tel 1986. El militare el farà governar co un consejo de Stato soto la lejer de Justin Lekhanya che el voea governar el paexe co el Re Moshoeshoe II e un grupo de ministri nomenai da el Re. Lekhanya el voea tornar al governo democratego in tel 1992, ma un colpo de Stato el fa in tel 1991. El Re Moshoeshoe II no el voea tornar a Lesotho par esser un Re ceremonial e el so fiol Letsie III el fa el posto. In tel 1995, el Re Letsie el abdicava in favor de el so pare, che no el moriva in tel 1996 in un incidente de auto. El Re Letsie III el torna al trono. Da quel momento Lesotho el viveva sempre con instabilitate politic, co frequente mutinies da parte del exercito e la policia, ma anca con tentativi de colpo de Stato. El ultimo tentativo, in tel agosto 1998, el fa el Re a chiedere l'intervento de le forse de defensa de la Comunità del Sud Africa. Soldai de Sud Africa, Zimbabwe e Botswana i entra in Lesotho e i restaura l'ordine. L'autorità provisoria che governava Lesotho la canbiava la lege electoral par garantir che la opozision la avese anca representation in parlamento.<end_of_turn>
# 0.1984152180490188
# ==========================================================================================
# Test Example
# Su la stésa piasa se fasa infin el Palaso dei Provedituri, abitasion dei governaturi de la fortésa, ancuo ospitante na mostra de ojetìstica. In antico duto el paéxe el gera sircuìo da un sistema de muri, butai xó 'ntel'Otosento, de cui ancuo resta sólo el Bastion de San Tono (su cui ghe xe poi sorta la fàbrica "Maruzzella") e puchi altri framinti. La Ceza prinsipal, in via Sinodo, la xe la Ceza de San Martin, che la risal al Setesento. In ela i vigniva custodìi anca dei reliquiari coi presunti resti de San Vito, patron sitadin, rubai durante la prima guera mondial. Più distante dal séntro ghe xe invése la Ceza de la Madona de la Salute. Evolusion demografica
#  Aministrasion comunal
#  Note
#  Linganbi foresti
#  Le riserve naturali de Maran
#  Sito su Maran
#  Comuni de ła provincia de Udine
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **venetian**, without any additions, explanations, or interpretations.
#
# It is the same pleasure to walk through the streets of the old town, the former residence of the fortress governor, now hosting an exhibition of artifacts. In ancient times the country was surrounded by a wall system, but only a few remains are left, including the Bastion of San Tono (where the Maruzzella factory later arose) and a few other fragments. The main church, in Via Sinodo, is the Church of San Martino, which dates back to the 17th century. Inside it also preserved the reliquary with the alleged remains of San Vito, the patron saint, stolen during the First World War. Further from the center is the Church of the Madonna della Salute. Demographic evolution
#   Communal administration
#   Notes
#   Sister cities
#   The natural reserve of Marano
#   Site on Marano
#   Comune in the province of Udine<end_of_turn>
# <start_of_turn>model
# Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#   Marano
#
# 0
# ==========================================================================================
# Test Example
# Co ła xe conpletamente vegnuda fora, ła farfała ła manda dal'estremo del'adome un łìquido dito meconio, chel contien tute łe robe de scarto prodote inte el stato de bigato. Daspò che ła xe łìbera, ła farfała ła resta co łe ałi piegae e pendołante, e łe verxa ponpando emolinfa inte łe nervadure ałare. El xe inportante che łe ałe del bao łe se verxa bastansa de presa prima che łe devénte dure; in caco contrario, łe restaria deformae par sénpre. Adulto: Ła farfała completamente cresùa ła ga un tipo de vita conpletamente desferente da queo del rugo: mentre sto qua el magnava muci de foge par creser, ła farfała ła pasa el ténpo a suciar el nètar dei fióri e a acopiarse. In xenere ła vita da farfała ła xe bastansa curta: se pasa da qualche giórno a na sitimana o dó e, soło in qualche caxo, ła pol rivar al mexe de vita. Par exenpio, l'Ocio de paon (Inachis io), ła fa un letargo prima de łasiar grupi de più de 500 vóvi par volta ai prinsipi de ła primavera, dónca ła xe bona a superar dó stagion. Ła farfała più granda che ghe xe ła xe ła Farfała de ła regina Lisandra (Ornithoptera alexandrae) che ła pol rivar a verxer łe ałe par 31 cm, ła ga na łonghesa del corpo de 8 cm e un pexo fin a 12 grami. Note
#  Cołigamenti da fora
#  Progeto ARVe: Farfałe Vèneto
#  Butterfly arc de Montegroto
#  Altri projeti
#  Baùti
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **english** to **venetian**, without any additions, explanations, or interpretations.
#
# When it is completely dry, the butterfly sends a liquid called meconium from the extreme end of the abdomen, which contains all the waste produced in the being of the chrysalis. After being released, the butterfly remains with its wings folded and hanging, and it takes a few hours to pump blood into the wing veins. It is important that the wings of the butterfly are fully expanded before they become hard; otherwise, they would remain deformed forever.
#
# Adult: the completely grown butterfly has a completely different type of life from that of the chrysalis: while staying here it eats a lot of food to grow, the butterfly spends its time sipping the nectar of flowers and mating. Generally, the life of a butterfly is quite short: it goes from a few days to a week or two, and only in some cases can it reach up to a month of life.
#
# For example, the Peacock's Eye (Inachis io) makes hibernation before laying groups of more than 500 eggs at a time in early spring, thus being able to overcome two seasons. The largest butterfly that exists is the Queen Alexandra's Birdwing (Ornithoptera alexandrae), which can reach a wingspan of 31 cm, it has a body length of 8 cm and a weight of up to 12 grams.<end_of_turn>
# <start_of_turn>model
# Co che el xe completamente seco, el bisardo el manda na roba liquida ciamà meconio da l'estrema parte de l'ano, chel ga dentro tuto el scartio che el fa durante el periodo de la crisalide. Dopo che el xe sta fora, el bisardo el resta co le ali tegnue e tegnue, e el fa un po' de ore par farghe el sangue in le vene de le ali. El xe importante che le ali del bisardo le sia tegnue completamente spese prima che le diventte dure; altrimenti, le restarà deformate par sempre. Adulto: el bisardo completamente cresto el ga na vita completamente diversa da chel de la crisalide: mentre che el resta qua el magna tanto de roba par farghe cresse, el bisardo el pasa il tempo a sorsegar la nettle de le rose e a fare le coppie. In genere, la vita de un bisardo la xe tanto breve: el va da poche dì a una settimana o due, e solo in alcuni casi se pol rivar a un mese de vita. Par esempio, el bisardo del ojo del pavone (Inachis io) el fa la dormide prima de farghe le coppie de più de 500 uova in primavera, in modo da poter superare due stagioni. El bisardo pi grande che existe el xe el bisardo del ojo del pavone (Ornithoptera alexandrae), che el pol rivar a un span de 31 cm, el ga un corpo de 8 cm e un peso fino a 12 g.<end_of_turn>
# 0.06684911419460503
# ==========================================================================================
# Test Example
# He was reunified under the control of the communist government of North Vietnam, renamed the Socialist Republic of Vietnam, on July 2, 1976. According to the government in Hanoi, the war caused the deaths of between 2 and 5.7 million people, the majority of whom were non-military.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **interlingua** to **english**, without any additions, explanations, or interpretations.
#
# Le nation esseva reunificate sub le controlo del governamento communista del Vietnam del Nord, renominate le Republica Socialista de Vietnam, le 2 de julio 1976. Secundo le governamento de Hanoi, le guerra ha causate le morte de inter 2 a 5,7 milliones de personas, le majoritate de istes non militar. Guerra Frigide<end_of_turn>
# <start_of_turn>model
# The nation was reunified under the control of the communist government of Vietnam, the People's Republic of Vietnam, on July 2, 1976. According to the government of Hanoi, the war had caused the death of between 2 and 5.7 million people, most of whom were not military.<end_of_turn>
# 0.5903196006402867
# ==========================================================================================
# Test Example
# How to alter giant planets, the planetary system of Uranus has a system of rings, a magnetosphere, and several natural satellites. The system of Uranus has a unique configuration with respect to the other planets because its axis of rotation is much inclined, almost parallel to its plane of revolution around the Sun. For this reason, its north and south poles are where the majority of the other planets have their equator. Seen from Earth, the rings of Uranus give the appearance that they are surrounding the planet like a target, and that the satellites are orbiting around it like the hands of a clock, but in 2007 and 2008, the rings appeared inclined. On January 24, 1986, the images of Voyager 2 showed Uranus as a planet without any special visible characteristics, and even without cloud bands or storms associated with the other giants. However, terrestrial observers have seen signs of a change of season and an increase in meteorological activity in the last year as Uranus approaches its equinox. The wind speed in Uranus can reach or even surpass 250 meters per second (900 km/h). Uranus is one of the planets that has a retrograde rotation; the other is Venus.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **interlingua** to **english**, without any additions, explanations, or interpretations.
#
# Como altere planetas gigante, le planeta Urano ha un systema de anulos, un magnetosphera, e plure satellites natural. Le systema de Urano habe un configuration unic respecto a le altere planetas proque su axe de rotation es multo inclinate, quasi usque su plano de revolution circum le sol. Por iste causa, su polo nord et sud se incontra ubi le majoria del altere planetas habe le equator. Viste ab le terra, le anulos de Urano da le aspecto de que illos circumfere le planeta como un diana, et que le satellites gira circum illo como le acos de un horologio, ma in 2007 et 2008, le anulos appareva inclinate. Le 24 de januario de 1986 le imagines del Voyager 2 monstrava Urano como un planeta sin alcuna characteristica special de luce visibile e mesmo sin bandas de nubes o tempestas associate con le altere gigantes. Tamen, le observatores terrestre ha viste signales de cambio de saison et un augmento in le activitate metereologic in le ultime annos a mesura que Urano approcha su equinoctio. Le velocitates del vento in Urano pote attinger o mesmo superpassar le 250 metros por secundo (900km/h). Urano es un del planetas que habe un rotation retrograde; le altere es Venus. Referentia
# Articulo de Urano ex Encyclopedia Britannica
#  Planetas<end_of_turn>
# <start_of_turn>model
# He is a planet that has a retrograde rotation; the other is Venus. References
#  Article on Urano from Encyclopedia Britannica
#  Planets<end_of_turn>
# 0.04175910319253394
# ==========================================================================================
# Test Example
# This late medieval alchemical tradition continued to play an important role in the development of modern science (particularly chemistry and medicine). Modern discussions of alchemy are usually divided into an examination of their practical exoteric applications and their spiritual esoteric aspects, notwithstanding criticisms from scholars such as Eric J. Holmyard and Marie-Louise von Franz that they should be understood as complementary. The former is studied by historians of physical science, who examine the subject in terms of chemistry, medicine and charlatanism, and the philosophical and religious contexts in which it took place. The latter interest historians of esotericism, psychologists and some philosophers and spiritualists. The subject has also had a continued impact on literature and the arts.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **interlingua** to **english**, without any additions, explanations, or interpretations.
#
# Iste tradition alchemic medieval tardive continuava a haber un importante rol in le disveloppamento del scientia de modernitate (particularmente chimia e medicina). Le discussiones moderne de alchimia es generalmente separate in un examination de lor applicatos practice exoteric e lor aspectos spiritual esoteric, nonobstante le criticas de studiosos tal como Eric J. Holmyard e Marie-Louise von Franz que illos debe esser comprehendite como complementari. Le prime es studiate per historiatores del scientias physic, qui examina le subjecto in terminos de chimia, medicina e charlatanismo, e le contextos philosophic e religiose in le quales iste eventos occurreva. Le secunde interessa le historiatores de esotericismo, psychologos, e alcun philosophos e spiritualistas. Le subjecto ha etiam facite un impacto continu in litteratura e artes.<end_of_turn>
# <start_of_turn>model
# The medieval alchemical tradition continued to have an important role in the development of modern science (particularly chemistry and medicine). The discussion of alchemical ideas is generally separated into an examination of their practical exoteric applications and their spiritual esoteric aspects, not to mention the criticisms of scholars such as Eric Holmyard and Marie- Louise von Franz that they should be understood as complementary. The first is studied by historians of science, who examine the subject in terms of chemistry, medicine, and charlatanism, and the philosophical and religious contexts in which these events occurred. The second is studied by historians of esotericism, psychology, and some philosophers and spiritualists. The subject has also had a continuing impact on literature and art.<end_of_turn>
# 0.5975480120915752
# ==========================================================================================
# Test Example
# Chomsky's viewpoint is also not free from criticism. Thus, for learning theorists, this is a point of view against the innatist perspective on the apparent ability of animals, such as chimpanzees, to learn the rudiments of language. Language investigations reveal the existence of individual differences in its acquisition, not only in relation to its start and rapid development, but also in the use of different learning mechanisms and in the use of evolutionarily non-exact routes. Lenneberg, in contrast to this, the hypothesis of a critical period in its acquisition, as initially formulated by Lenneberg, does not seem to be supported in the current state. This investigator is based, to a large extent, on the fact that the period in which language acquisition is generally located is between two years and twelve, after which it can be acquired; and, on the other hand, in the existence of language recoveries in people who suffer from aphasia in formative ages, but not (or very defective) in aphasic adults. Results of later investigations put into evidence the ability to acquire language after this period considered critical. Nevertheless, despite its acquisition, development is not normal. It seems to exist a 'sensitive' period (16 months - 8 years, approximately) in which the essentials of linguistic development are produced.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **interlingua** to **english**, without any additions, explanations, or interpretations.
#
# Le puncto de vista de Chomsky tamben non care de criticas. Assi, pro le theoricos del apprendissage illo es un puncto de vista in contra del perspectiva innatista al apparente capacitate del animales, tal como le chimpanzes, pro apprender le rudimentos del linguage. Le investigationes super le linguage pone de manifesto le existentia de differentias individual in le acquisition de illo, non solo in relation a su initio e rapiditate de disveloppamento, si non tamben in le uso de differente mechanismos de apprendissage e in le uso de routes evolutive non exactemente equal. Lenneberg
# In contraste a isto, le hypothese de un periodo critic in su acquisition, tal como esseva initialmente formulate per Lenneberg, non pare esser sustenite in le actualitate. Iste investigator se basava, in grande parte, in le facto de que le periodo in le que se situa generalmente le acquisition del linguage es inter un periodo inter le duo annos usque le dece-duo, sin que pote esser acquirite a partir de iste etate; e per
# altere parte, in le existentia de recuperationes de linguage in personas qui suffreva aphasia in etates formative, ma non (o multo defective) in adultos aphasic. Resultatos de investigationes posterior pone in evidentia le capacitate pro acquirir le linguage depois de iste periodo considerate como critic. Non obstante, malgrado su acquisition, le disveloppamento non es normal. Il pare exister un periodo ‘sensibile’ (16 menses - 8 annos, approximatemente) in le qual se produce lo essential del disveloppamento linguistic. Psychologia<end_of_turn>
# <start_of_turn>model
# He also does not care for criticism. So, for the theorists of learning, it is a point of view in contrast to the innate perspective, at the apparent capacity of animals, such as chimpanzees, to learn the rudiments of language. The investigation of language makes it clear that there are individual differences in the acquisition of it, not only in relation to its beginning and rapid development, but also in the use of different learning mechanisms and in the use of non-exact evolutionary routes. Lenneberg
#
# In contrast to this, the hypothesis of a critical period in its acquisition, as was initially formulated by Lenneberg, does not seem to be supported in the present. This investigator based, in large part, on the fact that the period in which language acquisition generally occurs is between one and two years, without being able to acquire it after this age; and on the other hand, in the existence of language recovery in people who suffer from aphasia in their formative years, but not (or not at all) in adults with aphasia. The results of subsequent research make it clear that the capacity to acquire language after this period is not limited. However, despite its acquisition, development is not normal. It seems that there is a period 'sensitive' (16 months - 8 years, approximately) in which the essential development of linguistic development occurs. Psychology<end_of_turn>
# 0.46869241542642
# ==========================================================================================
# Test Example
# Some editions have only a few hundred nights, but others have 1001 or more nights. The collection, or at least certain stories of it, or pretending to be of it, were known in the West in the 18th century, after which they were translated - first into French, then English, and other European languages. Some of the most famous stories of the Nights, especially Aladdin's Wonderful Lamp, Ali Baba and the Forty Thieves, and The Seven Voyages of Sinbad the Sailor, although they were probably genuine Arabic folk-tales, were not part of the Nights in their Arabic version, but were interpolated into the collection by the first European translator. Books
# ...
#
# Nota
# Altri progetti
# Lingua foresta
# Sanità negli Stati Uniti d'America
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# Se no se se iscrive par ła parte B dai 3 mezi antesedenti al conpimento dei 65 ani finmente ai 3 mezi drioman a sta data, se pagarà na penałe che ła consta inte un 10% ano par ogni ano inte el cuało no se se iscrive. Oltre che a ła parte A e B łe ghe ze altre do parte: ła parte C, conosesta cofà Medicare Advantage, ła cuała ła ofre piani de asistensa sanitària zestii da socetà aseguratore privae reconoseste da Medicare; sti piani i fa ciapare vantaji a łe parte A e B e ai so servisi e i concore al pagamento dei fàrmaghi co prescrision; ła parte D, invese, ła concore al pagamento de łe speze dei fàrmaghi, ła sbasa łe speze dei fàrmaghi prescrivesti e ła proteze da l’inalsamento del costo de sti fàrmaghi. Notasion
#  Altri projeti
#  Linganbi foresti
#  Sanità inte i Stati Unii de l'Amèrica<end_of_turn>
# <start_of_turn>model
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# Se no se iscrive par la parte B dai 3 mesi precedenti al conpimento dei 65 anni fino al 3 mesi dopo la data di oggi, si paga una pena che consta in un 10% anno per ogni anno in cui non si iscrive. Oltre a la parte A e B, ci sono altre due parti: la parte C, conosciuta come Medicare Advantage, che offre piani di assistenza sanitaria zestii da parte di società assicuratrici privae riconosciute da Medicare; questi piani fanno ciapare vantaggi a la parte A e B e ai suoi servizi e i concorrono al pagamento dei farmaci con prescrizione; la parte D, invece, concorre al pagamento dei farmaci, si basa sulla prescrizione dei farmaci e si protegge da l'insorgere del costo di questi farmaci.<end_of_turn>
# 0.2752826882217419
# ==========================================================================================
# Test Example
# Il primo comandante in capo della Wehrmacht fu il feldmaresciallo Werner von Blomberg, che fu destituito nel 1938 dal Führer Adolf Hitler, che da quel momento assunse anche la guida suprema delle forze armate tedesche. La Wehrmacht, che aveva conquistato una eccezionale e straordinaria reputazione di efficienza bellica nel corso della seconda guerra mondiale e che aveva occupato per un certo periodo di tempo gran parte dell'Europa, è considerata la più grande forza combattente della storia tedesca e la più dotata di grande potere rispetto a qualsiasi altra formazione militare germanica mai esistita.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# El primo comandante in cao de ła Wehrmacht el ze sta el feldmaresało Werner von Blonberg che el zera sta destituio inte el 1938 dal Führer Adolf Hitler che el ghea ciapà da cuel momento anca ła guida suprema de łe forse armae todesche. La Wehrmacht, che ła ghea concuistà na ecesionałe e straordenària reputasion de eficensa bèłega inte el ndar de ła seconda guera mondiałe e ła ghea ocupà par un serto perìodo de tenpo granda parte de l'Eoropa, ła vien considerada ła pì granda forsa conbatente de ła istòria todesca e cueła dotada de pì grando podere in confronto a calsìase altra formasion miłitare zermànega mai ezistia. Notasion
#  Altri projeti
#  Linganbi foresti
#  Wehrmacht<end_of_turn>
# <start_of_turn>model
# Il primo comandante in capo della Wehrmacht era stato il feldmarescial Werner von Blonberg che era stato destituito nel 1938 dal Führer Adolf Hitler. La Wehrmacht, che aveva conquistato una eccezionale e straordinaria reputazione di efficienza bellica in un periodo di tempo grandioso, era considerata la più grande forza combattente di storia tedesca e dotata di più grande potere in confronto a altre formazioni militari.
#
# Nota:
# Altri progetti
# Linganbi foresto
# Wehrmacht<end_of_turn>
# 0.33587540072531474
# ==========================================================================================
# Test Example
# il musicista rock a metà degli anni sessanta ha iniziato a privilegiare l'album come forma principale di espressione e consumo di musica registrata, con i Beatles in prima linea in questo sviluppo. La loro abilità contribuì a conferire al genere una legittimità culturale nel mainstream e portò alla creazione di album rock che dominarono l'industria musicale nei decenni successivi. Nel periodo del "classic rock" alla fine degli anni sessanta, erano emersi numerosi sottogeneri di musica rock, tra cui ibridi come blues rock, folk rock, country rock, southern rock, raga rock e jazz rock, molti dei quali contribuirono allo sviluppo del rock psichedelico, influenzato dalla controcultura degli anni '60 psichedelica e hippy. Un nuovo scenario emerse successivamente, che includeva il rock progressivo, che estendeva l'elemento artistico, il glam rock, che metteva in risalto lo spettacolo e lo stile visivo, e il sottogenere variegato e duraturo dell'heavy metal, che enfatizzava il volume, la potenza e la velocità. Nella seconda metà degli anni settanta, il punk rock produsse una critica sociale e politica essenziale e energica. Il punk influenzò negli anni ottanta il new wave, il post-punk e infine il rock alternativo.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# I muzeghisti rock a metà dei anni sesanta i ga tacà priviłezar l'àlbun so'l singoło cofà forma prinsipałe de espresion e consumo de mùzega rezistrada, co i Beatles in prima łinea in 'sto zviłupo. I só contribudi i ghe ga conferìo a'l zènare na łezitimità culturałe inte'l mainstream e i ga invià n'era de àlbun rock che i ga dominà l'industria muzegal inte i deseni sucesivi. Inte'l parìodo de'l "classic rock" de ła fine dei ani sesanta, A zera za emerzesti numarozi sotozènari distinti de mùzega rock, incluzi ibridi come blues rock, folk rock, country rock, southern rock, raga rock e jazz rock, tanti dei cuałi i ghe ga contribuìo a'l zviłupo de'l rock psichedełico, influensà da ła controcultura dei ani 1960 psichedełica e hippy. Novi zènari emerzesti drioman i includeva el rock progresivo, che'l estendeva i ełementi artìsteghi, el glam rock, che'l meteva in resalto el spetacoło e el stiłe vizivo, e el sotozènare vario e duraùro de l'heavy metal, che'l enfatizava el vołume, ła potensa e ła vełosità. Inte ła segonda metà inte i ani setanta el punk rock el ga reazìo produzendo critiche sosiałe e połìteghe esensiałe ed enèrzeghe. El punk el ga avùo n'influensa inte i ani otanta so ła new wave, so'l post-punk e infin so'l rock alternativo. Notasion
#  Genari muxicałi
# Pàjine co erori inte łe nòde<end_of_turn>
# <start_of_turn>model
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# I muzeghi rock a metà dei anni sessanta i ga tacà priviłegà l'àlbun so'l singoło cofà forma prinsipałe de espresion e consumo de mùzega rezistrada, co i Beatles in prima łinea in 'sto zviłupo. I só contribudi i ghe ga conferìo a'l zènare na łezitimità culturałe inte'l mainstream e i ga invià n'era de àlbun rock che i ga dominà l'industria muzegal inte i deseni sucesivi. Inte'l parìodo de'l "classic rock" de ła fine dei ani sesanta, A zera za emerzesti numarozi sotozènari distinti de mùzega rock, incluzi ibridi come blues rock, folk rock, country rock, southern rock, raga rock e jazz rock, tanti dei cuałi i ghe ga contribuìo a'l zviłupo de'l rock psichedełico, influensà da ła controcultura dei ani 1960 psichedełica e hippy. Novi zènari emerzesti drioman i includeva el rock progresivo, che'l estendeva i ełementi artìsteghi, el glam rock, che'l meteva in resalto el spetacoło e el stiłe vizivo, e el sotozènare vario e duraùro de l'heavy metal, che'l enfatizava el vołume, ła potensa e ła vełosità. Inte ła segonda metà inte i ani setanta el punk rock el ga reazìo produzendo critiche sosiałe e połìteghe esensiałe ed enèrzeghe. El punk el ga avùo n'influensa inte i ani otanta so'l new wave, so'l post-punk e infin so'l rock alternativo. Notasion
#  Genari muxicałi
# Pàjine co erori inte łe nòde<end_of_turn>
# 0.10330901373212979
# ==========================================================================================
# Test Example
# L'impero, dopo una lunga crisi, ha finito di esistere nel 1453 (conquista di Costantinopoli da parte dei turchi ottomani guidati da Maometto II). Nato il 17 gennaio 395 e caduto il 29 maggio 1453, quell'impero bizantino è l'impero che è durato di più in tutta la storia della Terra, con 1058 anni di stato paròn; se si vuole considerare come la vera e propria continuazione dell'impero romano, è durato dal 27 a.C. fino al 1453, essendo stato paròn per 1480 anni.
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# L'inpero, dopo na longa crizi, el ga finìo de exìstar inte el 1453 (conquista de Costantinopoli da parte dei turchi otomani guidà da Maometto II). Nato el 17 de zenaro 395 e cascà el 29 de majo 1453, cueło bizantin el xé l'inpero che xe durà de pi in tuta ła storia de la Tera, con 1058 anni da stato paròn; se si vol considerarlo come ła vera e propria continuasion de l'inpero roman, el xe durà dal 27 a.C. fin al 1453, esendo cusita stà paròn par 1480 ani. Altri projeti
#  Linganbi foresti
#  Storia de l'Axia
# Istòria de l'Eoropa
# Età de mexo<end_of_turn>
# <start_of_turn>model
# L'inpero, dopo na longa crizi, el ga finìo de exìstar inte el 1453 (conquista de Costantinopoli da parte dei turchi otomani guidà da Maometto II). Nato el 17 de zenaro 395 e cascà el 29 de majo 1453, cueło bizantin el xé l'inpero che xe durà de pi in tuta ła storia de la Tera, con 1058 anni da stato paròn; se si vol considerarlo come ła vera e propria continuasion de l'inpero roman, el xe durà dal 27 a.C. fin al 1453, esendo cusita stà paròn par 1480 ani. Altri projeti
#  Linganbi foresti
#  Storia de l'Axia
#  Storia de l'Eoropa
#  Età de mexo<end_of_turn>
# 0.12580237753817397
# ==========================================================================================
# Test Example
# Peruggia avrebbe rubato la Gioconda alla Galleria degli Uffizi a Firenze per raccogliere milioni di lire . Egli dichiarò che il suo atto era un atto patriottico e che l'Italia avrebbe dato maggior valore all'opera . E procedettero con la condanna per Peruggia il 4 e 5 giugno del 1914 a Firenze , e con una folla di persone che lo sostenevano sapendo che era un eroe fuori dal tribunale , il giudice emise la sentenza per lui una pena di un anno e undici mesi di prigione . Il 29 luglio la pena gli fu ridotta a sette mesi e otto giorni , ma la pena che era stata emessa Peruggia era stata già scontata . Bibliografia
#   Hoobler , Dorothy e Thomas , I crimini di Parigi New York : Little , Brown , 2009 , pp . 3 - 7 , 305 - 314 . Kuper , Simon , " Chi ha rubato la Gioconda ? Il più famoso furto d'arte al mondo , 100 anni dopo , " Slate , 7 agosto 2011 . Newsweek , " Il ladro della Gioconda , " 29 settembre 1947 , p. 97 . Nota
#   altro progetto
#   Lingue straniere
#   Vanity Fair - maggio 2009 . " Rubare la Gioconda " di Dorothy e Thomas Hoobler
#   Saturday Evening Post : 100 anni fa : il genio dietro il furto della Gioconda
#   criminali italiani
# ------------------------------------------------------------------------------------------
# Model Response
# <start_of_turn>user
# Provide a direct translation of the following text from **venetian** to **italian**, without any additions, explanations, or interpretations.
#
# Peruggia el garia vołesto véndar ła Joconda a ła Galleria degli Uffizi de Firense par racuanti milioni de lire. El ghea declarà che ła soa ła zera na asion patriòtega e che l'Itàlia ła garia savesto darghe pì vałore a ła òpara. E proceso de condana par Peruggia el se ga vesto inte el 4 e 5 de zugno del 1914 a Firense, e co na foła de zente che el ło sostegnea par el so sesto eròego inte el de fora del tribunałe, i zùdezi i ghea sentensià par eło na pena in prezon de solché un ano e cuìndaze dì. Inte el 29 de lujo ła pena ła ghe zera stada scursada a sete mezi e oto dì, ma pena che ła zera stada fata ła sentensa Peruggia el zera sta descarserà. Bibliografia
#  Hoobler, Dorothy and Thomas, The Crimes of Paris New York: Little, Brown, 2009, pp. 3–7, 305–314. Kuper, Simon, "Who Stole the Mona Lisa? The World's Most Famous Art Heist, 100 Years On," Slate, 7 August 2011. Newsweek, "The Mona Lisa Thief," 29 September 1947, p. 97. Notasion
#  Altri projeti
#  Linganbi foresti
#  Vanity Fair - May 2009. "Stealing Mona Lisa" by Dorothy and Thomas Hoobler
#  Saturday Evening Post: 100 Years Ago: The Mastermind Behind the Mona Lisa Heist
#  Crimenałi itałiani<end_of_turn>
# <start_of_turn>model
# Perugia il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a Firenze dal 10 al 13 maggio 2014. Il Garia Volo è il nome della mostra che si terrà a Palazzo Pitti a
# 1.7107277069483648e-155
# ==========================================================================================
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
corpus_metric([v[0] for v in _results], [v[1] for v in _results])
# Out:
# 0.16540055248618785

# %%
_results = []
for test_example, model_response in zip(outputs, extract_response(res_decode)):
    print("Test Example")
    print(test_example)
    print("---" * 30)
    print("Model Response")
    print(model_response)
    m = sentence_metric(model_response, test_example, bleu)
    _results.append((model_response, test_example, m))
    print(m)
    print("===" * 30)
# Out:
# Test Example
# Le majoritate de su obras explora le thema de solitate. García Márquez moriva de pneumonia al etate de 87 in Citate de Mexico. A su morte, Juan Manuel Santos, le presidente de Colombia, le describeva como "le Colombiano le plus magne qui unquam viveva."
#  Gente colombian
# Scriptores
# Laureatos del Premio Nobel pro Litteratura
# ------------------------------------------------------------------------------------------
# Model Response
# La mayoría de su trabajo explora el tema de la soledad. García Márquez murió de pneumonia a los 87 años en la Ciudad de México. En su muerte, Juan Manuel Santos, el presidente de Colombia, describió como "el mayor colombiano que ha vivido".
# Colombianos
# Escritores
# Nobel laureates en Literatura
# 2.5473825510753416e-78
# ==========================================================================================
# Test Example
# La agricoltura no la ze mai stata la economia principal. Al paeset al ze famoss par la tradision dei consa che da qua i partia par l'Italia e par i Stati confinanti co pochi arte par far e inpajar carieghe. I consa par difender al so saer e par parlarse intrà de lori sensa esser intendesti i se ga inventà an so gergo ciamà "Scapelament del consa". Al gosaldin Giocondo Dalle Feste del 2003 al ga publicà an disionario de le parole de sto gergo. Forsela Aurine
# Quota su el livel del mar 1300m. La frasion la ospita struture par al turismo estivo e invernal e la ze te el altipian a i piei del Agner e de la Croda Granda. La frasion, piciola assei, la ze abitada pi che sia da turisti (i paesani i ze 19). Personalità de Gosalt
#  Jacom Dalle Feste al ga scrit an disionario su el Scapelament del consa. Robe da no perderse
#  La Ceza del paess, dedicada a San Jacomo, la ze del 1100. Prodoti tipici
#  Carieghe
#  Comuni de ła provincia de Bełun
# ------------------------------------------------------------------------------------------
# Model Response
# Agriculture was never the main economy. The country is famous for its tradition of the language that from here departs to Italy and to the bordering states with a little art to do and learn cargo. The language is used to defend the knowledge of being and to speak among themselves without being understood they invented a jargon called "Scapelament of the language". In 2003, Giocondo published a dictionary of the words of this jargon.
# 7.043849426292939e-232
# ==========================================================================================
# Test Example
# L'illustratore della seconda edizione (la prima pubblicata in un volume indipendente) dello Studio in rosso è Charles Doyle, il padre dell'autore. Le immagini più famose di Holmes e Watson sono state create da Sidney Paget, l'illustratore della maggior parte dei racconti. Watson, con un sigaro in mano, ascolta Holmes nella seguente illustrazione di Paget :
# ------------------------------------------------------------------------------------------
# Model Response
# : Le illustrazioni del secondo volume (le prime pubblicate in un volume indipendente) di Un Studio in Scarlato erano Charles Doyle, il padre dell'autore. Le immagini più famose di Holmes e Watson erano create da Sidney Paget, l'illustratore di maggior parte dei contos. Watson, con un cigarro in mano, ascolta Holmes in le sequenze di illustrazioni per Paget:
# 0.40435085755435507
# ==========================================================================================
# Test Example
# Drìo la lejenda Marìa ła ga parlà de nòu: Coromoto, inrabià, el ga proà a ciaparla co un braso, ma ela la xe sparia. Par la tradision sta aparision la se ga schisà su un màrchio de fibra de àlbara, che incoi se pòl vexer tel santuario nasionałe de Nostra Signora de Coromoto. Te la s-ciòna Coromoto el é morxist de na bisa co 'l velen: el el torna a Guanare, drìo a morir, e el domanda el batexo che ghe vèn dato de in barinas. Coromoto el guarise del velen e el ciapa el nòme de Angelo Custode. Pò el domanda a i endìxeni cospes ncora pagani che (anca par colpa soa) no i se èra batexadi de farlo. Culto
#  Papa Pio XII, tel 1950, el ga dichiarà Nòsa Siora del Coromoto patròna del Venesuèla. Papa Giovani Pagoło II el ga incoronà la statua te la so vìxita al santuario marian de Guanare, e Papa Benedeto XVI el ga elevà el santuario nasional de Nòsa Siora del Coromoto a baxìlica minore. Collegamenti foresti
#  Sito ufisial de la Vèrgine del Coromoto
#  Venezuela Tuya
#  Ceza catòłega in Venesueła
# ------------------------------------------------------------------------------------------
# Model Response
# Secondo la leggenda Maria parlò a Coromoto, che provò a catturarla con un braccio, ma lei sparì.
# Secondo la tradizione si è seduta su un tronco d'albero, che ancora si può vedere nel santuario nazionale di Nostra Signora di Coromoto.
# Coromoto morì a Na bigu co' il velen : tornò a Guanare, morendo, e chiese il battesimo che non aveva ricevuto.
# Coromoto guarì dal veleno e prese il nome di Angelo Custode.
# Poi chiese agli indigeni cacciatori ancora pagani (e non battezzati per sua colpa) di farlo.
# Culto
# Papa Pio XII, nel 1950, dichiarò Nostra Signora di Coromoto patrona del Venezuela.
# Papa Giovanni Paolo II incoronò la statua nella piazza del santuario mariano di Guanare, e Papa Benedetto XVI elevò il santuario nazionale di Nostra Signora di Coromoto a basilica minore.
# 0.04464581987249571
# ==========================================================================================
# Test Example
# Rezistrasion
# El conbinamento de na tełecàmara e de un videorezistratore inte un ùgnoło dispozitivo portàtiłe e autoałimentà el ga zenarà ła videocàmara o camcorder, divegnesta partindo dal prinsìpio de ła dècada del 1980 ła sostitusion a łe cinepreze portàtiłi bazae su pełìcuła da 8 o 16 miłìmetri. Drio del tipo de dòpara, i vien doparai vari suporti de rezistrasion
#  nastri in caseta Betacam, VHS, S-VHS, VHS-C, S-VHS-C, Video8, Hi8, MiniDV, DVCam
#  dischi òteghi DVD-RAM, DVD
#  suporti in stato sołido cofà memòrie flash. rezistrasion de forma conpresa (de sòłito DivX): disco fredo. rezistrasion dizitałe: co ligamento Firewire o USB 2.0 par el trasferimento dei vìdeo su personal computer. Notasion
#  Altri projeti
#  Linganbi foresti
#  Dispoxidivi ełetròneghi
# ------------------------------------------------------------------------------------------
# Model Response
# La registrazione
# La combinazione di una telecamera e di un videoregistratore in un unico dispositivo portatile e autoalimentato ha generato la videocamera o camcorder, che è diventata, a partire dai primi anni '80, il sostituto del cineprese portatile a base di pellicola da 8 o 16 millimetri. A seconda del tipo di utilizzo, vengono utilizzati vari supporti di registrazione
# nastro in cassetta: Betacam, VHS, S-VHS, VHS-C, S-VHS-C, Video8, Hi8, MiniDV, DVCam
# disco ottico: DVD-RAM, DVD
# supporti a stato solido: memoria flash. Registrazione in forma compressa (di solito DivX): disco rigido. Registrazione digitale: collegamento Firewire o USB 2.0 per il trasferimento del video su personal computer. Note
# Altri progetti
# Lingue straniere
# Dispositivi elettronici
# 0.14979818650173055
# ==========================================================================================
# Test Example
# The total number of known amphibian species is approximately 7000, of which almost 90% are frogs. The smallest amphibian (and vertebrate) in the world is a new Guinea frog (Paedophryne amauensis) with a length of only 7.7 millimeters. The largest living amphibian is the 1.8-meter-long Chinese Giant Salamander (Andrias davidianus) but is nearing extinction, the 9-meter-long Prionosuchus from the Middle Permian of Brazil. The study of amphibians is called batrachology, but the study of both reptiles and amphibians is called herpetology.
# ------------------------------------------------------------------------------------------
# Model Response
# The total number of known species of amphibians is approximately 7,000, of which almost 90% are frogs. The largest living amphibian is the Chinese Salamandra Gigante (Andrias davidianus) which is 1.8 meters long, but it is extinct. The largest living amphibian is the Chinese Salamandra Gigante (Andrias davidianus) which is 1.8 meters long, but it is extinct.
# 0.20858372544069118
# ==========================================================================================
# Test Example
# ACE può servire come rappresentazione della conoscenza, specificazione e linguaggio di consultazione e può essere concepito per professionisti che vogliono utilizzare notazioni formali e metodi formali, ma che potrebbero non essere familiari con esso. Benché ACE sembri perfettamente naturale - può essere letto e compreso da chiunque - è in realtà un linguaggio formale. Il motore di analisi Attempto (APE) traduce testo ACE senza ambiguità in strutture di rappresentazione del discorso (DRS) che utilizzano una variante del linguaggio logico di primo ordine. Le DRS possono poi essere tradotte in un altro linguaggio formale, ad esempio AceRules con varie semantica, RuleML, OWL e SWRL. Tradurre le DRS nel linguaggio standard della logica di primo ordine consente agli utenti di ragionare sul testo ACE, ad esempio per verificarlo, validarne la coerenza e consultarlo. ACE e gli strumenti correlati sono stati utilizzati nei campi di specificazione del software, prova del teorema, riassunto del testo, ontologia, regole, consultazione, documentazione medica e pianificazione. Nel 2004, ACE è stato adottato come linguaggio naturale controllato della rete europea di eccellenza REWERSE (Ragionamento sul web con regole e semantica). Riferimenti Collegamenti esterni Progetto Attempto Linguaggi controllati Traduttore da linguaggio a regole Linguistica computazionale Rappresentazione della conoscenza
# ------------------------------------------------------------------------------------------
# Model Response
# ```
# ACE potrebbe servire come modello per la rappresentazione del pensiero, specificando la lingua di consulta e la formulazione di regole.
# ```
# 2.2446408405888927e-155
# ==========================================================================================
# Test Example
# In 2002, Hawking esseva classificate numero 25 in le sondage del BBC del 100 Plus Grande Britannos. Hawking habeva un forma rar, precoce e de progression lente de maladia motoneuronal (tamben cognoscite como sclerosis lateral amyotrophic o maladia de Lou Gehrig) que progressivemente le paralysava durante decennios. Mesmo post haber devenite mute, ille poteva continuar communicar per medio de un apparato de generation de linguage, initialmente con le adjuta de un interruptor manual, e finalmente con un sol musculo del gena. Ille moriva le 14 de martio 2018 al etate de 76 annos. Como un actor, ille jocava le personage de ille ipse in quatro episodios del sitcom The Simpsons e septe del sitcom The Big Bang Theory,, e ille jocava un simulation holographic de ille ipse in un episodio del serie Star Trek: The Next Generation. Referentias
#  Laureatos del Premio Nobel pro Physica
# Physicos
# Gente britannic
# Actores de Star Trek
# Star Trek
# Actores de The Big Bang Theory
# Actores e actrices de The Big Bang Theory
# The Big Bang Theory
# Foramines Nigre
# Cosmologia
# ------------------------------------------------------------------------------------------
# Model Response
# Nel 2002, Hawking è stato classificato al numero 25 nel sondaggio della BBC dei 100 più grandi britannici. Hawking soffriva di una rara forma precoce e lentamente progressiva di malattia motoneurone (noto anche come sclerosi laterale amiotrofica o malattia di Lou Gehrig) che lo paralizzò progressivamente nel corso dei decenni. Anche dopo essere diventato muto, potette continuare a comunicare attraverso un apparecchio per la generazione del linguaggio, inizialmente con l'aiuto di un interruttore manuale e infine con un solo muscolo del ginocchio. Morì il 14 marzo 2018 all'età di 76 anni. Come attore, interpretò se stesso in quattro episodi della sitcom I Simpson e sette della sitcom The Big Bang Theory, e interpretò una simulazione olografica di se stesso in un episodio della serie Star Trek: The Next Generation.
# 0.06720467099500901
# ==========================================================================================
# Test Example
# In 1882, Edison pressed the button of the first large-scale electric network that provided 110 volt DC (direct current) to 59 customers in Manhattan. In 1887, Nikola Tesla submitted a number of patents for AC (alternating current) distribution. AC has replaced DC for electricity generation and distribution. Tesla's work on induction motors and polyphase systems has influenced the specialty for the future, and Edison worked on telegraphy and his company became General Electric.
#
# Modern developments
#  Emergence of radio and electronics
#  In the classic ultra-high frequency UHF experiments of 1888, Heinrich Hertz transmitted and detected radio waves using electric equipment. In 1895, Nikola Tesla made transmissions at a distance of 80.4 km.
#
# Education
#  Electrical engineers have an academic degree with a major in electrical engineering. The length of study is 5 years.
#
# Gallery
#  Related disciplines
#  Mechatronics
#  See also
#  Analog signal processing
#  Battery charger
#  Computer engineering
#  Electronic design automation
#  Electric motor
#  Electric vehicle
#  Electronic engineering
#  IEEE
#  Institution of Engineering and Technology (IET)
#  List of electrical engineering topics (alphabetical)
#  List of electrical engineering topics (thematic)
#  List of electrical engineers
#  Muntzing
#  Net metering
#  Plug-in hybrid
#  V2G
#  References
# ------------------------------------------------------------------------------------------
# Model Response
# In 1882, Edison clicked the button of the first electric network at a large scale that provided 110 volts DC (direct current) to 59 customers in Manhattan. In 1887, Nikola Tesla submitted a number of patents for the distribution of current as AC (alternating current). AC has re-implanted DC for the generation and distribution of electric energy. Tesla's labor in motor of induction and polyphase system has influenced the specialty for the future, and Edison has labored in telegraphy and the company has become General Electric. Developments modern Emerge
# 0.20139625193710173
# ==========================================================================================
# Test Example
# They are believed to have been under the influence of hashish and opium during their killings or during their training. The word "assassin" originates from either Hashishin, the influence of the drugs, or hassansin, in consideration of their leader, Hassan-i Sabbah.
# ------------------------------------------------------------------------------------------
# Model Response
# On reputa que le assassinos esseva sub le influentia de hashish e opium durante lor occideres o durante lor trainamento. Le parola "assassino" origina en either hasishin, le influentia del drogas, o hassansin, per consideration por lor leader, Hassan-i Sabbah.
# 1.5359921273551537e-78
# ==========================================================================================
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
corpus_metric([v[0] for v in _results], [v[1] for v in _results])
# Out:
# 0.12051077414205906
